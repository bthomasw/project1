# %%
#import data
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
df = pd.read_csv('Sleep_health_and_lifestyle_dataset.csv')
df.head()
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# 2                 6                       60             8       Normal
# 3                 4                       30             8        Obese
# 4                 4                       30             8        Obese
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0         126/83          77         4200            NaN
# ...

# %%
#Still working on this 

stress_and_sleep = df[["","sleep time"]]

# Set the index to be "State" so they will be used as labels
screen_and_sleep = screen_and_sleep.set_index("screen time")

screen_and_sleep
age_and_sleep = df[["Stress Level","Sleep Duration"]]

# Use DataFrame.plot() in order to create a bar chart of the data
screen_and_sleep.plot(kind="bar", figsize=(20,3.5))

# Set a title for the chart
plt.title("Screen Time vs Sleep Time")

plt.tight_layout()
plt.show()
# Set the index to be "State" so they will be used as labels
age_and_sleep = age_and_sleep.set_index("Stress Level")
df.plot(kind="bar", figsize=(8,8),
              title="Age vs Sleep Duration")
plt.show()

# %%
#Going to add linear regression equation
age_and_sleep = df[["Age","Sleep Duration"]]

# Set the index to be "State" so they will be used as labels
age_and_sleep = age_and_sleep.set_index("Age")
df.plot(kind="scatter", x="Age", y="Sleep Duration", grid=True, figsize=(8,8),
              title="Age vs Sleep Duration")
plt.show()
