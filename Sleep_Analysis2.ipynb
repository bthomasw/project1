# %%
from pathlib import Path
import pandas as pd
file_path = Path("Sleep_health_and_lifestyle_dataset.csv")

# %%
sleep_health_and_lifestyle_part_1 = pd.read_csv(file_path, encoding="UTF-8")
sleep_health_and_lifestyle_part_1.sort_values("Age")
sleep_health_and_lifestyle_part_1
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# ...

# %%
#sleep_health_and_lifestyle.count()

# %%
sleep_health_and_lifestyle_part_1 = sleep_health_and_lifestyle_part_1.fillna('None')
sleep_health_and_lifestyle_part_1
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# ...

# %%
sleep_health_and_lifestyle_part_1.count()
# Out:
# Person ID                  374
# Gender                     374
# Age                        374
# Occupation                 374
# Sleep Duration             374
# Quality of Sleep           374
# Physical Activity Level    374
# Stress Level               374
# BMI Category               374
# Blood Pressure             374
# Heart Rate                 374
# Daily Steps                374
# Sleep Disorder             374
# dtype: int64

# %%
file_path = Path("Sleep_health_and_lifestyle_dataset_part_2.csv")
sleep_health_and_lifestyle_part_2 = pd.read_csv(file_path, encoding="UTF-8")
sleep_health_and_lifestyle_part_2.sort_values("Age")
sleep_health_and_lifestyle_part_2
# Out:
#      Person ID  Gender  Age   Occupation  Sleep Duration  Quality of Sleep  \
# 0          374  Female   59        Nurse             8.1                 9
# 1          375    Male   29       Doctor             7.8                 7
# 2          376    Male   29       Doctor             7.8                 7
# 3          377    Male   29       Doctor             6.1                 6
# 4          378    Male   29       Doctor             7.8                 7
# ..         ...     ...  ...          ...             ...               ...
# 181        555  Female   43      Teacher             6.7                 7
# 182        556    Male   43  Salesperson             6.5                 6
# 183        557  Female   43      Teacher             6.7                 7
# 184        558    Male   43  Salesperson             6.4                 6
# 185        559    Male   43  Salesperson             6.5                 6
#
# ...

# %%
sleep_health_and_lifestyle_part_2 = sleep_health_and_lifestyle_part_1.fillna('None')
sleep_health_and_lifestyle_part_2
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# ...

# %%
dfs = [sleep_health_and_lifestyle_part_1, sleep_health_and_lifestyle_part_2]
combined_df = pd.concat(dfs)
print(combined_df.count())
# Out:
# Person ID                  748
# Gender                     748
# Age                        748
# Occupation                 748
# Sleep Duration             748
# Quality of Sleep           748
# Physical Activity Level    748
# Stress Level               748
# BMI Category               748
# Blood Pressure             748
# Heart Rate                 748
# Daily Steps                748
# Sleep Disorder             748
# dtype: int64

# %%
combined_cleaned_df = combined_df.drop_duplicates()
print(combined_cleaned_df.count())
# Out:
# Person ID                  374
# Gender                     374
# Age                        374
# Occupation                 374
# Sleep Duration             374
# Quality of Sleep           374
# Physical Activity Level    374
# Stress Level               374
# BMI Category               374
# Blood Pressure             374
# Heart Rate                 374
# Daily Steps                374
# Sleep Disorder             374
# dtype: int64

# %%
occupations = combined_df['Occupation'].value_counts()

# %%
occupations.count()
# Out:
# 11

# %%
occupations.plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
combined_df['Sleep Disorder'].value_counts()
# Out:
# Sleep Disorder
# None           438
# Sleep Apnea    156
# Insomnia       154
# Name: count, dtype: int64

# %%
sleep_apnea = combined_df[combined_df['Sleep Disorder'] == 'Sleep Apnea']
sleep_apnea.count()
# Out:
# Person ID                  156
# Gender                     156
# Age                        156
# Occupation                 156
# Sleep Duration             156
# Quality of Sleep           156
# Physical Activity Level    156
# Stress Level               156
# BMI Category               156
# Blood Pressure             156
# Heart Rate                 156
# Daily Steps                156
# Sleep Disorder             156
# dtype: int64

# %%
insomnia = combined_df[combined_df['Sleep Disorder'] == 'Insomnia']
insomnia.count()
# Out:
# Person ID                  154
# Gender                     154
# Age                        154
# Occupation                 154
# Sleep Duration             154
# Quality of Sleep           154
# Physical Activity Level    154
# Stress Level               154
# BMI Category               154
# Blood Pressure             154
# Heart Rate                 154
# Daily Steps                154
# Sleep Disorder             154
# dtype: int64

# %%
occupations_sleep_apnea = sleep_apnea['Occupation'].value_counts()
occupations_sleep_apnea.plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
occupations_insomnia = insomnia['Occupation'].value_counts()
occupations_insomnia.plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
combined_cleaned_df.head()
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# 2                 6                       60             8       Normal
# 3                 4                       30             8        Obese
# 4                 4                       30             8        Obese
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0         126/83          77         4200           None
# ...

# %%
combined_cleaned_df.plot.scatter(x = 'Sleep Duration', y = 'Stress Level')
# Out:
# <Axes: xlabel='Sleep Duration', ylabel='Stress Level'>

# %%
combined_cleaned_df.plot.scatter(x = 'Sleep Duration', y = 'BMI Category')
# Out:
# <Axes: xlabel='Sleep Duration', ylabel='BMI Category'>

# %%
combined_cleaned_df.plot.scatter(x = 'Sleep Duration', y = 'Daily Steps')
# Out:
# <Axes: xlabel='Sleep Duration', ylabel='Daily Steps'>

# %%
combined_cleaned_df.plot.scatter(x = 'Sleep Duration', y = 'Sleep Disorder')
# Out:
# <Axes: xlabel='Sleep Duration', ylabel='Sleep Disorder'>

# %%
combined_cleaned_df.plot.scatter(x = 'Sleep Duration', y = 'Occupation')
# Out:
# <Axes: xlabel='Sleep Duration', ylabel='Occupation'>

# %%
df = combined_df.groupby('Occupation')['Sleep Duration'].mean()

# %%
df = df.sort_values(ascending = False)

# %%
df.plot.bar()
# Out:
# <Axes: xlabel='Occupation'>

# %%
df = combined_df.groupby('Sleep Disorder')['Sleep Duration'].mean()
df = df.sort_values(ascending = False)
df.plot.bar()
# Out:
# <Axes: xlabel='Sleep Disorder'>

# %%
df = combined_df.groupby('BMI Category')['Sleep Duration'].mean()
df = df.sort_values(ascending = False)
df.plot.bar()
# Out:
# <Axes: xlabel='BMI Category'>

# %%
df = combined_df.groupby('Stress Level')['Sleep Duration'].mean()
df = df.sort_values(ascending = False)
df.plot.bar()
# Out:
# <Axes: xlabel='Stress Level'>

# %%
df = combined_df.groupby('Occupation')['Stress Level'].mean()
df = df.sort_values(ascending = False)
df.plot.bar()
# Out:
# <Axes: xlabel='Occupation'>
