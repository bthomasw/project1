# %%
from pathlib import Path
import pandas as pd
file_path = Path(r"C:\Users\ernes\Desktop\project1\Sleep_health_and_lifestyle_dataset.csv")

# %%
sleep_health_and_lifestyle = pd.read_csv(file_path, encoding="UTF-8")
sleep_health_and_lifestyle.head()
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# 2                 6                       60             8       Normal
# 3                 4                       30             8        Obese
# 4                 4                       30             8        Obese
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0         126/83          77         4200            NaN
# ...

# %%
sleep_health_and_lifestyle.count()
# Out:
# Person ID                  374
# Gender                     374
# Age                        374
# Occupation                 374
# Sleep Duration             374
# Quality of Sleep           374
# Physical Activity Level    374
# Stress Level               374
# BMI Category               374
# Blood Pressure             374
# Heart Rate                 374
# Daily Steps                374
# Sleep Disorder             155
# dtype: int64
