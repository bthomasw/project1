# %%
#import data
import pandas as pd
df = pd.read_csv('covid-19 data.csv')
df.head()
# Out:
#     NCT Number                                        Study Title  \
# 0  NCT04395300  Sleep Quality in Healthcare Personnel During C...
#
#                                       Study URL  Acronym Study Status  \
# 0  https://clinicaltrials.gov/study/NCT04395300      NaN    COMPLETED
#
#                                        Brief Summary Study Results  \
# 0  Coronavirus disease 2019 (COVID-19), represent...            NO
#
#                               Conditions            Interventions  \
# 0  COVID-19|Sleep Quality|General Health  OTHER: Web Based Survey
#
#                             Primary Outcome Measures  ...  \
# 0  measure sleep quality in healthcare worker, Pi...  ...
#
#                                 Study Design  Other IDs  Start Date  \
# 0  Observational Model: |Time Perspective: p  AssiutU14  2020-03-30
#
#    Primary Completion Date Completion Date First Posted  Results First Posted  \
# ...
